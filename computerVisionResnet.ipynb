# %%
# !pip install lightning-utilities
# !pip install torchmetrics --no-deps
# Install the torchinfo package for showing the network information
# !pip install torchinfo --no-deps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.7/931.7 kB 13.3 MB/s eta 0:00:00
# ...

# %%
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from tqdm import tqdm
import torch
import torch.nn as nn
import torchvision
from torchvision.transforms import v2
from torchvision.transforms.functional import to_pil_image
from torchmetrics import MeanMetric, Accuracy
from torchmetrics import ConfusionMatrix, Accuracy, Precision, Recall, F1Score
from torchinfo import summary

# %%
# Make sure to change runtime to GPU
# Check if GPU is avaiable
device = "cuda" if torch.cuda.is_available() \
else "mps" if torch.mps.is_available() \
else "cpu"
print("Device:", device)
# Out:
# Device: cuda

# %%
# !unzip archive.zip -d raf-db-dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: raf-db-dataset/DATASET/train/5/train_00987_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_00990_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_00991_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_00992_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01002_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01010_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01011_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01013_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01015_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01017_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01039_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01048_aligned.jpg
#   inflating: raf-db-dataset/DATASET/train/5/train_01049_aligned.jpg
# ...

# %%
model = torchvision.models.alexnet()

# %%
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
# ...

# %%
model = torchvision.models.vgg16()

# %%
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
# ...

# %%
model = torchvision.models.resnet18()

# %%
train_data = torchvision.datasets.ImageFolder("raf-db-dataset/DATASET/train", transform=train_transform)
val_data = torchvision.datasets.ImageFolder("raf-db-dataset/DATASET/train", transform=eval_transform)
test_set = torchvision.datasets.ImageFolder("raf-db-dataset/DATASET/test", transform=eval_transform)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8e4e9bc26044> in <cell line: 0>()
# ----> 1 train_data = torchvision.datasets.ImageFolder("raf-db-dataset/DATASET/train", transform=train_transform)
#       2 val_data = torchvision.datasets.ImageFolder("raf-db-dataset/DATASET/train", transform=eval_transform)
#       3 test_set = torchvision.datasets.ImageFolder("raf-db-dataset/DATASET/test", transform=eval_transform)
#
# NameError: name 'train_transform' is not defined
